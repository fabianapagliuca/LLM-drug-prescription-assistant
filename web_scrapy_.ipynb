# %% [markdown]
# <a href="https://colab.research.google.com/github/fabianapagliuca/LLM-drug-prescription-assistant/blob/main/web_scrapy_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scarico bugiardini con Scrapy da sito https://www.farmaciemedici.it/farmaci/bugiardino/elenco-farmaci/a

# %%
#install scrapy
# !pip install scrapy
# !pip install transformers datasets
# !pip install numba
# !pip install transformers[torch] --use-deprecated=legacy-resolver
# Out:
# Collecting scrapy
#   Downloading scrapy-2.13.4-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.12/dist-packages (from scrapy) (43.0.3)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from scrapy) (0.7.1)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.12.2-py3-none-any.whl.metadata (22 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.3.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from scrapy) (5.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from scrapy) (25.0)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.10.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading protego-0.5.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting pydispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pyopenssl>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from scrapy) (24.2.1)
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.8.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting twisted<=25.5.0,>=21.7.0 (from scrapy)
#   Downloading twisted-25.5.0-py3-none-any.whl.metadata (22 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.3.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting zope-interface>=5.1.0 (from scrapy)
#   Downloading zope_interface-8.1.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=37.0.0->scrapy) (2.0.0)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.12/dist-packages (from service-identity>=18.1.0->scrapy) (25.4.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.12/dist-packages (from service-identity>=18.1.0->scrapy) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.12/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.2)
# Collecting automat>=24.8.0 (from twisted<=25.5.0,>=21.7.0->scrapy)
#   Downloading automat-25.4.16-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from twisted<=25.5.0,>=21.7.0->scrapy)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from twisted<=25.5.0,>=21.7.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from twisted<=25.5.0,>=21.7.0->scrapy)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (4.15.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from tldextract->scrapy) (3.11)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from tldextract->scrapy) (2.32.4)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.12/dist-packages (from tldextract->scrapy) (3.20.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy) (2.23)
# Requirement already satisfied: setuptools>=61.0 in /usr/local/lib/python3.12/dist-packages (from incremental>=24.7.0->twisted<=25.5.0,>=21.7.0->scrapy) (75.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2025.10.5)
# Downloading scrapy-2.13.4-py3-none-any.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.6/321.6 kB 14.6 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading itemadapter-0.12.2-py3-none-any.whl (18 kB)
# Downloading itemloaders-1.3.2-py3-none-any.whl (12 kB)
# Downloading parsel-1.10.0-py2.py3-none-any.whl (17 kB)
# Downloading protego-0.5.0-py3-none-any.whl (10 kB)
# Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Downloading queuelib-1.8.0-py3-none-any.whl (13 kB)
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading twisted-25.5.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 43.5 MB/s eta 0:00:00
# Downloading w3lib-2.3.1-py3-none-any.whl (21 kB)
# Downloading zope_interface-8.1.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 6.7 MB/s eta 0:00:00
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 7.0 MB/s eta 0:00:00
# Downloading automat-25.4.16-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.1 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.4 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Installing collected packages: pydispatcher, zope-interface, w3lib, queuelib, protego, jmespath, itemadapter, incremental, hyperlink, cssselect, constantly, automat, twisted, requests-file, parsel, tldextract, service-identity, itemloaders, scrapy
# Successfully installed automat-25.4.16 constantly-23.10.4 cssselect-1.3.0 hyperlink-21.0.0 incremental-24.7.2 itemadapter-0.12.2 itemloaders-1.3.2 jmespath-1.0.1 parsel-1.10.0 protego-0.5.0 pydispatcher-2.0.7 queuelib-1.8.0 requests-file-3.0.1 scrapy-2.13.4 service-identity-24.2.0 tldextract-5.3.0 twisted-25.5.0 w3lib-2.3.1 zope-interface-8.1.1
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.12/dist-packages (from numba) (2.0.2)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (4.67.1)
# Requirement already satisfied: torch>=2.2; extra == "torch" in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.8.0+cu126)
# Requirement already satisfied: accelerate>=0.26.0; extra == "torch" in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (1.11.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers[torch]) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3; platform_machine == "x86_64" or platform_machine == "amd64" or platform_machine == "arm64" or platform_machine == "aarch64" in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers[torch]) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers[torch]) (2025.10.5)
# Requirement already satisfied: setuptools; python_version >= "3.12" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.12/dist-packages (from torch>=2.2; extra == "torch"->transformers[torch]) (3.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.0; extra == "torch"->transformers[torch]) (5.9.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2; extra == "torch"->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2; extra == "torch"->transformers[torch]) (3.0.3)

# %%
#import library
import scrapy
from scrapy.crawler import CrawlerProcess
from datasets import Dataset
import pandas as pd
import json
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import datasets

# %%
from numba import cuda

# %%
import torch
import torch.nn as nn
from transformers import AutoConfig

# %% [markdown]
# Dataframe

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import os
from twisted.internet import reactor # Import reactor

class DrugSpider(scrapy.Spider):
    name = "farmaci"
    start_urls = [
        "https://www.farmaciemedici.it/farmaci/bugiardino/elenco-farmaci/a",
        "https://www.farmaciemedici.it/farmaci/bugiardino/elenco-farmaci/b"]

    def parse(self, response):
        for drug in response.css("div.card-title h3 a"):  # Seleziona tutti gli elementi "a" (link) all'interno di h3 dentro <div con la classe (card-title)
            url = response.urljoin(drug.css("::attr(href)").get())  # Combina più link per ottenere quello completo. Utile quando si segue link di pagine correlate
            nome = drug.css("::text").get().strip()  # Estrae il nome, .strip() leva gli spazi
            yield scrapy.Request(url, callback=self.parse_drug, meta={'nome': nome})

    def parse_drug(self, response):
        nome = response.meta['nome']  # Recupera il nome del farmaco passato tramite meta.

        def extract_detail(selector):  # Estrae il testo usando il selettore CSS, unisce le parti di testo e rimuove gli spazi bianchi.
            detail = response.css(selector).getall()
            return ' '.join([d.strip() for d in detail]) if detail else None

        controindicazioni = extract_detail("h3#controindicazioni_farmaco + p::text, h3#controindicazioni_farmaco + p *::text")
        somministrazione = extract_detail("h3#somministrazione_farmaco + p::text, h3#somministrazione_farmaco + p *::text")
        effetti = extract_detail("h3#effetti_farmaco + p::text, h3#effetti_farmaco + p *::text")
        dosaggio = extract_detail("h3#dosaggi_farmaco + p::text, h3#dosaggi_farmaco + p *::text")
        gravidanza = extract_detail("h3#gravidanza_farmaco + p::text, h3#gravidanza_farmaco + p *::text")

        principio_attivo = extract_detail("p span[itemprop='activeIngredient']::text")
        informazioni_aggiuntive = extract_detail("h2 + p::text, h2 + p *::text")
        prezzo = extract_detail("div.col-md-7 > p:contains('prezzo')")

        if prezzo:
            prezzo_text = scrapy.Selector(text=prezzo).css("span[itemprop='cost']::text").get()
            prezzo = f"il prezzo rilevato per la vendita di questo farmaco è di circa {prezzo_text}€ a confezione."



        yield {  # Genero un dizionario con tutte le informazioni raccolte sul farmaco.
            "nome": nome,
            "principio_attivo": principio_attivo,
            "prezzo": prezzo,
            "informazioni_aggiuntive": informazioni_aggiuntive,
            "controindicazioni_farmaco": controindicazioni,
            "somministrazione_farmaco": somministrazione,
            "effetti_farmaco": effetti,
            "dosaggio_farmaco": dosaggio,
            "gravidanza_farmaco": gravidanza
        }

# Configurare e avviare il processo di Scrapy

# Check if the reactor is already running and stop it if necessary
if reactor.running:
    reactor.stop()

process = CrawlerProcess(settings={
    'FEED_FORMAT': 'json',  # Formato JSON del dizionario
    'FEED_URI': 'farmaci2.json',  # Specifico il percorso e il nome del file di output
    'LOG_LEVEL': 'INFO',
})

process.crawl(DrugSpider)
process.start()
# Out:
# INFO:scrapy.utils.log:Scrapy 2.13.4 started (bot: scrapybot)
# 2025-11-17 15:45:27 [scrapy.utils.log] INFO: Scrapy 2.13.4 started (bot: scrapybot)
# INFO:scrapy.utils.log:Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.6.105+-x86_64-with-glibc2.35'}
# 2025-11-17 15:45:27 [scrapy.utils.log] INFO: Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.6.105+-x86_64-with-glibc2.35'}
# INFO:scrapy.addons:Enabled addons:
# []
# 2025-11-17 15:45:27 [scrapy.addons] INFO: Enabled addons:
# []

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Crea il DataFrame dal file JSON
with open('farmaci2.json', 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data)

# %%
# Conta i valori None in ogni colonna
none_counts = df.isna().sum()

print(none_counts)
# Out:
# nome                          0
# principio_attivo              0
# prezzo                        0
# informazioni_aggiuntive       0
# controindicazioni_farmaco    12
# somministrazione_farmaco     13
# effetti_farmaco              13
# dosaggio_farmaco             21
# gravidanza_farmaco           15
# dtype: int64

# %%
df_cleaned = df.dropna()
# Mostra il numero di righe rimosse
rows_removed = len(df) - len(df_cleaned)
print(f"Numero di righe rimosse: {rows_removed}")
# Out:
# Numero di righe rimosse: 30

# %%
file_path = '/content/drive/My Drive/TESI/dataset_bugfarmaciULTIMO2.csv'
df_cleaned.to_csv(file_path, index=False)

# %%
import pandas as pd
import json

df_new_sorted = df_cleaned.sort_values(by='nome')

print(df_new_sorted)
# Out:
#          nome                                   principio_attivo  \
# 1        Abba                     Amoxicillina/acido clavulanico
# 517   Abesart                                         Irbesartan
# 516   Abilify                                       Aripiprazolo
# 512  Abiostil  Neomicina/Eucaliptolo/Pino Essenza/Canfora/Men...
# 514      Abis                                         Amlodipina
# ..        ...                                                ...
# 264  Busilvex                                          Busulfano
# 260   Busoded                                         Budesonide
# 261    Buspar                                          Buspirone
# 259  Bydureon                                          Exenatide
# 258    Byetta                                          Exenatide
#
#                                                 prezzo  \
# 1    il prezzo rilevato per la vendita di questo fa...
# 517  il prezzo rilevato per la vendita di questo fa...
# 516  il prezzo rilevato per la vendita di questo fa...
# 512  il prezzo rilevato per la vendita di questo fa...
# 514  il prezzo rilevato per la vendita di questo fa...
# ..                                                 ...
# 264  il prezzo rilevato per la vendita di questo fa...
# 260  il prezzo rilevato per la vendita di questo fa...
# 261  il prezzo rilevato per la vendita di questo fa...
# 259  il prezzo rilevato per la vendita di questo fa...
# 258  il prezzo rilevato per la vendita di questo fa...
#
#                                informazioni_aggiuntive  \
# 1    ABBA è un antibiotico che funziona uccidendo i...
# 517  Trattamento dell'ipertensione essenziale. Trat...
# 516  ABILIFY è indicato per il trattamento della sc...
# 512  ABIOSTIL unguento nasale è indicato per il tra...
# 514  Il Farmaco Abis è indicato nella cura dell'Ipe...
# ..                                                 ...
# 264  Busilvex, seguito da ciclofosfamide (BuCy2) è ...
# 260  BUSODED è indicato nel trattamento dell’asma b...
# 261  Buspar  è indicato nel trattamento dei disturb...
# 259  BYDUREON è indicato nel trattamento del diabet...
# 258  BYETTA è indicato nel trattamento del diabete ...
#
#                              controindicazioni_farmaco  \
# 1    Il farmaco ABBA è controindicato in casi di ip...
# 517  Ipersensibilità nei confronti della sostanza a...
# 516  Durante il trattamento antipsicotico, il migli...
# 512  • Ipersensibilità ai principi attivi o ad uno ...
# 514  Abis e Amlodipina (principio attivo del farmac...
# ..                                                 ...
# 264  Ipersensibilità al principio attivo o ad uno q...
# 260  Ipersensibilità a budesonide. Tubercolosi polm...
# 261  Buspar  è generalmente controindicato in caso ...
# 259  Ipersensibilità al principio attivo o ad uno q...
# 258  Ipersensibilità al principio attivo o ad uno q...
#
#                               somministrazione_farmaco  \
# 1    La somministrazione del farmaco ABBA varia in ...
# 517  La usuale dose iniziale e di mantenimento racc...
# 516  Schizofrenia : la dose di partenza raccomandat...
# 512  ABIOSTIL è controindicato nei bambini fino ai ...
# 514  Sia per l’ipertensione che per l’angina, la do...
# ..                                                 ...
# 264  Concentrato per soluzione per infusione (conce...
# 260  USO RESPIRATORIO. Polvere per inalazione, caps...
# 261  BUSPAR 5 mg compresse BUSPAR 5 mg compresse  P...
# 259  Polvere e solvente per sospensione iniettabile...
# 258  Soluzione iniettabile (iniezione), penna preri...
#
#                                        effetti_farmaco  \
# 1    Come tutti i medicinali, ABBA può causare effe...
# 517  In studi clinici controllati con placebo su pa...
# 516  Come con altri antipsicotici, i pazienti devon...
# 512  Questo prodotto contiene derivati terpenici ch...
# 514  Amlodipina altera lievemente o moderatamente l...
# ..                                                 ...
# 264  Neutropenia Trombocitopenia Neutropenia febbri...
# 260  Reazioni di ipersensibilità immediate o tardiv...
# 261  Alle dosi terapeutiche buspirone è ben tollera...
# 259  Nausea Vomito Diarrea Dispepsia Dolore addomin...
# 258  Ostruzione Intestinale Nausea Vomito Diarrea D...
#
#                                       dosaggio_farmaco  \
# 1    Si consiglia sempre di assumere il farmaco ABB...
# 517  L’esperienza in adulti trattati con dosi fino ...
# 516  Negli studi clinici e nell'esperienza post - m...
# 512  In caso di assunzione orale accidentale o di e...
# 514  L’esperienza nei casi di sovradosaggio di Abis...
# ..                                                 ...
# 264  - 0,8 mg/kg di peso corporeo di busulfan in in...
# 260  Nei casi di asma severo all’inizio della terap...
# 261  Il dosaggio consigliato di Buspar è di 15 mg/d...
# 259  La dose raccomandata è 2 mg di exenatide una v...
# 258  La terapia con BYETTA deve essere iniziata con...
#
#                                     gravidanza_farmaco
# 1    In caso di gravidanza o sospetto di gravidanza...
# 517  l’uso di AIIRA non è raccomandato nel primo tr...
# 516  Non ci sono studi specifici e adeguatamente co...
# 512  Non vi sono o sono disponibili in numero limit...
# 514  La sicurezza di Abis durante la gravidanza non...
# ..                                                 ...
# 264  HPCT è controindicato nelle donne in gravidanz...
# 260  risultati emersi da ampi studi epidemiologici ...
# 261  Non sono stati effettuati studi controllati in...
# 259  Non vi sono dati adeguati provenienti dall’uso...
# 258  Non vi sono dati adeguati provenienti dall’uso...
#
# [526 rows x 9 columns]

# %%
file_path = '/content/drive/MyDrive/TESI/dataset_bugfarmaciULTIMO2.csv'

df_new_sorted.to_csv(file_path, index=False)

# %%
print(df_new_sorted['nome'])
# Out:
# 1          Abba
# 517     Abesart
# 516     Abilify
# 512    Abiostil
# 514        Abis
#          ...
# 264    Busilvex
# 260     Busoded
# 261      Buspar
# 259    Bydureon
# 258      Byetta
# Name: nome, Length: 526, dtype: object

# %%
print(df_new_sorted.iloc[0])
# Out:
# nome                                                                      Abba
# principio_attivo                                Amoxicillina/acido clavulanico
# prezzo                       il prezzo rilevato per la vendita di questo fa...
# informazioni_aggiuntive      ABBA è un antibiotico che funziona uccidendo i...
# controindicazioni_farmaco    Il farmaco ABBA è controindicato in casi di ip...
# somministrazione_farmaco     La somministrazione del farmaco ABBA varia in ...
# effetti_farmaco              Come tutti i medicinali, ABBA può causare effe...
# dosaggio_farmaco             Si consiglia sempre di assumere il farmaco ABB...
# gravidanza_farmaco           In caso di gravidanza o sospetto di gravidanza...
# Name: 1, dtype: object

# %%
file_path = '/content/drive/MyDrive/TESI/dataset_bugfarmaciULTIMO2.csv'
df = pd.read_csv(file_path)

print(df.head())
# Out:
#        nome                                   principio_attivo  \
# 0      Abba                     Amoxicillina/acido clavulanico
# 1   Abesart                                         Irbesartan
# 2   Abilify                                       Aripiprazolo
# 3  Abiostil  Neomicina/Eucaliptolo/Pino Essenza/Canfora/Men...
# 4      Abis                                         Amlodipina
#
#                                               prezzo  \
# 0  il prezzo rilevato per la vendita di questo fa...
# 1  il prezzo rilevato per la vendita di questo fa...
# 2  il prezzo rilevato per la vendita di questo fa...
# 3  il prezzo rilevato per la vendita di questo fa...
# 4  il prezzo rilevato per la vendita di questo fa...
#
#                              informazioni_aggiuntive  \
# 0  ABBA è un antibiotico che funziona uccidendo i...
# 1  Trattamento dell'ipertensione essenziale. Trat...
# 2  ABILIFY è indicato per il trattamento della sc...
# 3  ABIOSTIL unguento nasale è indicato per il tra...
# 4  Il Farmaco Abis è indicato nella cura dell'Ipe...
#
#                            controindicazioni_farmaco  \
# 0  Il farmaco ABBA è controindicato in casi di ip...
# 1  Ipersensibilità nei confronti della sostanza a...
# 2  Durante il trattamento antipsicotico, il migli...
# 3  • Ipersensibilità ai principi attivi o ad uno ...
# 4  Abis e Amlodipina (principio attivo del farmac...
#
#                             somministrazione_farmaco  \
# 0  La somministrazione del farmaco ABBA varia in ...
# 1  La usuale dose iniziale e di mantenimento racc...
# 2  Schizofrenia : la dose di partenza raccomandat...
# 3  ABIOSTIL è controindicato nei bambini fino ai ...
# 4  Sia per l’ipertensione che per l’angina, la do...
#
#                                      effetti_farmaco  \
# 0  Come tutti i medicinali, ABBA può causare effe...
# 1  In studi clinici controllati con placebo su pa...
# 2  Come con altri antipsicotici, i pazienti devon...
# 3  Questo prodotto contiene derivati terpenici ch...
# 4  Amlodipina altera lievemente o moderatamente l...
#
#                                     dosaggio_farmaco  \
# 0  Si consiglia sempre di assumere il farmaco ABB...
# 1  L’esperienza in adulti trattati con dosi fino ...
# 2  Negli studi clinici e nell'esperienza post - m...
# 3  In caso di assunzione orale accidentale o di e...
# 4  L’esperienza nei casi di sovradosaggio di Abis...
#
#                                   gravidanza_farmaco
# 0  In caso di gravidanza o sospetto di gravidanza...
# 1  l’uso di AIIRA non è raccomandato nel primo tr...
# 2  Non ci sono studi specifici e adeguatamente co...
# 3  Non vi sono o sono disponibili in numero limit...
# 4  La sicurezza di Abis durante la gravidanza non...

# %%
df.iloc[0]
# Out:
# nome                                                                      Abba
# principio_attivo                                Amoxicillina/acido clavulanico
# prezzo                       il prezzo rilevato per la vendita di questo fa...
# informazioni_aggiuntive      ABBA è un antibiotico che funziona uccidendo i...
# controindicazioni_farmaco    Il farmaco ABBA è controindicato in casi di ip...
# somministrazione_farmaco     La somministrazione del farmaco ABBA varia in ...
# effetti_farmaco              Come tutti i medicinali, ABBA può causare effe...
# dosaggio_farmaco             Si consiglia sempre di assumere il farmaco ABB...
# gravidanza_farmaco           In caso di gravidanza o sospetto di gravidanza...
# Name: 0, dtype: object
